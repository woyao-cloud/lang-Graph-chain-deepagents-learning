# %%
from langchain_core.prompts import PromptTemplate
from langchain_community.llms import Tongyi  # 导入通义千问Tongyi模型
import dashscope
import os

# 从环境变量获取 dashscope 的 API Key
api_key = os.getenv('DASHSCOPE_API_KEY')
dashscope.api_key = api_key
 
# 加载 Tongyi 模型
llm = Tongyi(model_name="qwen-turbo", dashscope_api_key=api_key) 

# 创建Prompt Template
prompt = PromptTemplate(
    input_variables=["product"],
    template="What is a good name for a company that makes {product}?",
)

# 新推荐用法：将 prompt 和 llm 组合成一个"可运行序列"
chain = prompt | llm

# 使用 invoke 方法传入输入
result1 = chain.invoke({"product": "colorful socks"})
print(result1)
# Out:
# A great name for a company that makes colorful socks should be fun, memorable, and reflect vibrancy and personality. Here are some creative suggestions:
#
# 1. **Hue & Heel** – A clever play on "hue" (color) and the part of the sock, suggesting style and color.
# 2. **Sole Mates** – A pun on "soul mates," implying your perfect sock match with a fun twist.
# 3. **Rainbow Treads** – Evokes vivid colors and the idea of stepping out in style.
# 4. **Sock It To Me!** – Energetic and bold, borrowing from the classic phrase.
# 5. **ChromaSteps** – Combines "chroma" (color intensity) with "steps," highlighting colorful footwear.
# 6. **Happy Soles** – Focuses on comfort and joy, with a double meaning (soles of feet + happy feelings).
# 7. **WildStride** – Suggests bold patterns and confidence in every step.
# 8. **TootSocks** – A playful, quirky name that stands out and is easy to remember.
# 9. **ColorSpun** – Implies socks spun with vibrant color and creativity.
# 10. **Zing Socks Co.** – Short, zippy, and full of energy—perfect for bold designs.
#
# Bonus tip: Pair the name with a fun logo (like a dancing sock or rainbow footprints) to enhance brand recognition!
#
# Would you like a more whimsical, modern, or luxury feel to the name? I can tailor more options based on your brand vibe.

# %%
result2 = chain.invoke({"product": "广告设计"})
print(result2)
# Out:
# A good name for a company that specializes in 广告设计 (advertising design) should be creative, memorable, and reflect qualities like innovation, visual impact, and strategic communication. Here are several name suggestions in both English and Chinese, depending on your target market:
#
# ### Bilingual / English Names:
# 1. **VisionEdge Creative** – Suggests sharp, forward-thinking design.
# 2. **Apex Ads Studio** – Implies top-tier advertising solutions.
# 3. **BoldFrame Design Co.** – Evokes strong visual composition and creativity.
# 4. **NovaAd Creative** – "Nova" suggests newness and brilliance; modern and catchy.
# 5. **PixelHive** – Great for a digital-focused ad design agency; implies collaboration and energy.
#
# ### Chinese Names (with meaning):
# 1. **创想无限 (Chuǎngxiǎng Wúxiàn)** – "Infinite Creativity" — emphasizes imagination and limitless ideas.
# 2. **锐视广告 (Ruìshì Guǎnggào)** – "Sharp Vision Advertising" — conveys clarity and impactful visuals.
# 3. **点睛设计 (Diǎnjīng Shèjì)** – "The Finishing Touch Design" — references the classic idiom about adding the pupils to a dragon painting, symbolizing the crucial final touch.
# 4. **新象创意 (Xīn Xiàng Chuàngyì)** – "New Image Creativity" — modern, fresh branding appeal.
# 5. **启点广告 (Qǐdiǎn Guǎnggào)** – "Starting Point Advertising" — suggests launching brands and ideas.
#
# ### Hybrid (English + Chinese):
# - **Lumos Creative | 朗目设计**
#   ("Lumos" = light in Latin; "朗目" = bright eyes — symbolizing vision and clarity)
#
# - **StellarAds | 星驰广告**
#   ("Star-speed" — fast, brilliant, and dynamic)
#
# ### Tips for Choosing:
# - Keep it easy to pronounce and remember.
# - Check domain availability (e.g., .com or .cn).
# - Ensure the name isn’t already trademarked in your region.
#
# Would you like the name to lean more toward Chinese-speaking markets, international clients, or something balanced? I can tailor suggestions further!
